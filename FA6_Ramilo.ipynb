# %%
#Number 1 FA6
from fractions import Fraction
from timeit import timeit
def iterative_exponent(input_base,input_exp):
    base = input_base
    limit = abs(input_exp)
    i=1
    while i<limit:
        base *= input_base 
        i+=1
    if input_exp > 0:
        return base
    elif input_exp < 0:
        return Fraction(1, base)
    else:
        return 1

def recursive_exponent(input_base,input_exp):
    if input_exp > 0:
        i=1
        if i < input_exp:
            return recursive_exponent(input_base*raw_base,input_exp-1)
        else:
            return input_base
    elif input_exp < 0:
        i=-1
        if i > input_exp:
            return recursive_exponent(input_base*raw_base,input_exp+1)
        else:
            return Fraction(1,input_base)
    else:
        return 1


input_base = float(input("\n\nBase: "))
raw_base = input_base
input_exp = int(input("Exponenet: "))
print(f"\nAnswer(iterative): {iterative_exponent(input_base,input_exp)}"); print(f"Answer(recursive): {recursive_exponent(input_base,input_exp)}")
iterative_exponent_time = timeit(lambda : iterative_exponent(input_base,input_exp), number=1)
recursive_exponent_time = timeit(lambda : recursive_exponent(input_base,input_exp), number=1)
print(f"\nTime(iterative): {iterative_exponent_time}"); print(f"Time(recursive): {recursive_exponent_time}");

if iterative_exponent_time < recursive_exponent_time:
    print("\nIterative is Faster")
else:
    print("\nRecursive is Faster")

#Conclusion: For smaller number inputs recurssion works faster than
    #iterative. For larget number inputs iterative works much faster
    #than recussion. Therefore depending on the inputs to which is faster
    #varies.

#Number 2 FA6
def iterative_two(n):
    total = 0
    while n>=0:
        total = total+2**n
        n-=1
    return total
def recursive_two(n):
    if n != 0:
        base_two= 2**n
        return (recursive_two(n-1)+base_two)
    else:
        return 1


raw_n = int(input("\n\nInput for n: "))
print(f"\nTotal(iterative): {iterative_two(raw_n)}"); print(f"Total(recirsive): {recursive_two(raw_n)}\n")
iterative_two_time = timeit(lambda : iterative_two(raw_n), number=1)
recursive_two_time = timeit(lambda : recursive_two(raw_n), number=1)
print(f"\nTime(iterative): {iterative_two_time}"); print(f"Time(recursive): {recursive_two_time}");

if iterative_two_time < recursive_two_time:
    print("\nIterative is Faster")
else:
    print("\nRecursive is Faster")

    #Conclusion: For smaller number inputs recurssion works faster than
        #iterative. For larget number inputs iterative works much faster
        #than recussion. Therefore depending on the inputs to which is faster
        #varies.
